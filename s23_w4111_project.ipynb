# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
# </style>
#
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# COMS W4111: Introduction to Databases<br>
# Spring 2023, Sections 002, V02
# </span>
# </center></b>
# </span><br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2">
# HW2, HW3, HW4 and Project Setup and Configuration Tests<br>
# </span>
# </center></i>

# %% [markdown]
# # Introduction

# %% [markdown]
# - Students should follow the instructions in the [Ed post for HW2](https://edstem.org/us/courses/32981/discussion/2617289). Specifically,
#     - The post references two GitHub repos/projects.
#         - https://github.com/donald-f-ferguson/W4111_FastAPI_IMDB_Api.git
#         - https://github.com/donald-f-ferguson/W4111_Data_Engineering_Project.git
#     - Programming track students must clone both repos.
#     - Non-programming track students must clone ```W4111_Data_Engineering_Project``` and may clone ```W4111_FastAPI_IMDB_Api```.
#     - Students in both tracks should follow the instructions for creating and loading the starter database described in the desction "Initial Data Load."
#
#
# - After completing the setup, the sections below contain configuration and setup tests.
#
#
# - __Remember:__ Follow the instructions in the project ```README.md``` for creating copies of directories and files. This will avoid code merges when the instructor updates or adds files.

# %% [markdown]
# # HW2 Setup Tests

# %% [markdown]
# ## Data Load

# %% [markdown]
# All students should complete these tests.

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
#
# Modify the statement below to use your MySQL password.
#
# %sql mysql+pymysql://root:dbuserdbuser@localhost

# %%
#
# Modify the statement below to use the loaded schema that you created
# when changing s23_w4111_hw2_dff to s23_w4111_hw2_<your UNI>.
#
# %sql use s23_w4111_hw2_dff
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# - Run the tests below. Your output should match the test output.

# %%
# %sql select count(*) as count from characters;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [(389,)]

# %%
# %sql select count(*) as count from episodes;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [(73,)]

# %%
# %sql select count(*) as count from name_basics;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [(730,)]

# %%
# %sql select count(*) as count from title_basics;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [(73,)]

# %%
# %%sql
#
# select
#     tconst, primary_title, original_title, seasonNum, episodeNum, episodeTitle
# from
#     title_basics join episodes on tconst=episodeLink
# order by
#     seasonNum, episodeNum;
# Out:
#  * mysql+pymysql://root:***@localhost
# 73 rows affected.
# [('tt1480055', 'Winter Is Coming', 'Winter Is Coming', 1, 1, 'Winter Is Coming'),
#  ('tt1668746', 'The Kingsroad', 'The Kingsroad', 1, 2, 'The Kingsroad'),
#  ('tt1829962', 'Lord Snow', 'Lord Snow', 1, 3, 'Lord Snow'),
#  ('tt1829963', 'Cripples, Bastards, and Broken Things', 'Cripples, Bastards, and Broken Things', 1, 4, 'Cripples, Bastards, and Broken Things'),
#  ('tt1829964', 'The Wolf and the Lion', 'The Wolf and the Lion', 1, 5, 'The Wolf and the Lion'),
#  ('tt1837862', 'A Golden Crown', 'A Golden Crown', 1, 6, 'A Golden Crown'),
#  ('tt1837863', 'You Win or You Die', 'You Win or You Die', 1, 7, 'You Win or You Die'),
#  ('tt1837864', 'The Pointy End', 'The Pointy End', 1, 8, 'The Pointy End'),
#  ('tt1851398', 'Baelor', 'Baelor', 1, 9, 'Baelor'),
#  ('tt1851397', 'Fire and Blood', 'Fire and Blood', 1, 10, 'Fire and Blood'),
#  ('tt1971833', 'The North Remembers', 'The North Remembers', 2, 1, 'The North Remembers'),
# ...

# %% [markdown]
# - I cleverly managed to mess up creating ```name_basics```. We are going to fix it.

# %%
import pandas as pd

# %%
name_basics_df = pd.read_csv("./data/s23_imdb_clean_name_basics.csv")

# %%
from sqlalchemy import create_engine

# %%
#
# Make sure you set your password properly.
#
engine = create_engine("mysql+pymysql://root:dbuserdbuser@localhost")

# %% [markdown]
# - __Note:__ Make sure you set the correct schema below.

# %%
name_basics_df.to_sql(
    "name_basics", 
    schema="s23_w4111_hw2_dff",
    if_exists="replace",
    index=False,
    con=engine)
# Out:
# 381

# %%
# %sql select * from name_basics;
# Out:
#  * mysql+pymysql://root:***@localhost
# 381 rows affected.
# [('nm0389698', 'B.J. Hogg', 1955.0, 2020.0, 'actor,music_department', 'tt0970411,tt0944947,tt0986233,tt1240982'),
#  ('nm0269923', 'Michael Feast', 1946.0, None, 'actor,composer', 'tt0472160,tt0162661,tt0120879,tt0362192'),
#  ('nm0727778', 'David Rintoul', 1948.0, None, 'actor', 'tt1655420,tt1139328,tt4786824,tt6079772'),
#  ('nm6729880', 'Chuku Modu', 1990.0, None, 'actor,writer,producer', 'tt4154664,tt2674426,tt6470478,tt0944947'),
#  ('nm0853583', 'Owen Teale', 1961.0, None, 'actor', 'tt0102797,tt0485301,tt0462396,tt0944947'),
#  ('nm0203801', 'Karl Davies', 1982.0, None, 'actor,producer', 'tt12879632,tt7366338,tt3428912,tt0944947'),
#  ('nm8257864', 'Megan Parkinson', None, None, 'actress', 'tt0944947,tt6636246,tt5761478,tt4276618'),
#  ('nm0571654', 'Fintan McKeown', None, None, 'actor', 'tt0944947,tt0111904,tt0166396,tt0112178'),
# ...

# %% [markdown]
# ## Web Application Test (Programming Track Only)

# %% [markdown]
# - Edit the file ```service_factory.py``` in the web application project. Change the code in the ```__init__()``` method to ```artist_context["database"] = "s22_W4111_hw2_dff"```, but use your UNI for the database.
#
#
# - Edit the file ```mysql_data_service.py```. Change the ```__init__()``` method in ```MySQLDataServiceConfig``` to use your DB password.
#
#
# - Start the application in PyCharm. You can do this by selecting ```main.py```, right clicking and selecting ```Run```.
#
#
# - Execute the following cells.

# %%
import requests

# %%
url = "http://localhost:8001/api/artist/nm0000293"

result = requests.get(url)

result
# Out:
# <Response [200]>

# %%
#
# If you got a 200 response, execute the following.
#
result.json()
# Out:
# {'data': {'nconst': 'nm0000293',
#   'title': None,
#   'first_name': 'Sean',
#   'middle_name': None,
#   'last_name': 'Bean',
#   'suffix': None,
#   'nickname': None,
#   'full_name': ' Sean  Bean ',
#   'birth_year': '1959',
#   'death_year': None},
#  'links': [{'rel': 'primaryProfessions',
#    'href': '/api/artists/nm0000293/primaryProfession'},
#   {'rel': 'knownForTitles', 'href': '/api/artists/nm0000293/knownForTitles'},
#   {'rel': 'self', 'href': '/api/artists/nm0000293'}]}

# %% [markdown]
# ## Sorry, Some More Data

# %% [markdown]
# - Execute the following cells.

# %%
title_principals_df = pd.read_csv("./data/s23_imdb_clean_title_principals.csv")

# %%
title_principals_df.to_sql(
    "title_principals",
    schema="s23_w4111_hw2_dff",
    if_exists="replace",
    index=False,
    con=engine)
# Out:
# 730

# %%
# %%sql
#
# use s23_w4111_hw2_dff;
#
# with one as (
#     select * from title_principals where tconst =
#         (select episodeLink from episodes where seasonNum=1 and episodeNum=1)
# )
# select * from one
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 10 rows affected.
# [('tt1480055', 10, 'nm0230361', 'producer', 'producer', None),
#  ('tt1480055', 1, 'nm0000293', 'actor', None, '["Eddard \'Ned\' Stark"]'),
#  ('tt1480055', 2, 'nm0004692', 'actor', None, '["Robert Baratheon"]'),
#  ('tt1480055', 3, 'nm0182666', 'actor', None, '["Jaime Lannister"]'),
#  ('tt1480055', 4, 'nm0265610', 'actress', None, '["Catelyn Stark"]'),
#  ('tt1480055', 5, 'nm0887700', 'director', None, None),
#  ('tt1480055', 6, 'nm1125275', 'writer', 'created by', None),
#  ('tt1480055', 7, 'nm1888967', 'writer', 'created by', None),
#  ('tt1480055', 8, 'nm0552333', 'writer', 'based on "A Song of Ice and Fire" by', None),
#  ('tt1480055', 9, 'nm0122251', 'producer', 'producer', None)]
